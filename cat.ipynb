# %%
# !pip install opencv-contrib-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-contrib-python in c:\users\23b3802\appdata\roaming\python\python39\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\23b3802\appdata\roaming\python\python39\site-packages (from opencv-contrib-python) (2.0.2)
# WARNING: You are using pip version 22.0.4; however, version 25.1.1 is available.
# You should consider upgrading via the 'C:\Program Files\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread("cat.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.imshow(img)
plt.title("Original Image")
plt.axis("off")

# 正确使用 kernel
kernel = np.ones((5, 5), np.float32) / 25
dst = cv2.filter2D(img, -1, kernel)

plt.subplot(1, 2, 2)
plt.imshow(dst)
plt.title("Filtered Image")
plt.axis("off")
plt.show()

# %%
# !{sys.executable} -m ensurepip --upgrade
# Out:
# Looking in links: c:\Users\23B3802\AppData\Local\Temp\tmpfy27n5li
# Requirement already satisfied: setuptools in c:\users\23b3802\appdata\local\uv\cache\archive-v0\bbis7rtk5ua5x-nfoca9h\lib\site-packages (80.3.1)
# Requirement already satisfied: pip in c:\users\23b3802\appdata\local\uv\cache\archive-v0\bbis7rtk5ua5x-nfoca9h\lib\site-packages (22.0.4)

# %%
# !{sys.executable} -m pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\23b3802\sample\.venv\lib\site-packages (from opencv-python) (2.0.2)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.11.0.86
# WARNING: You are using pip version 22.0.4; however, version 25.1.1 is available.
# You should consider upgrading via the 'C:\Users\23B3802\AppData\Local\uv\cache\archive-v0\bbIs7rTK5ua5x-NFOCa9h\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !{sys.executable} -m pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\23b3802\appdata\local\uv\cache\archive-v0\bbis7rtk5ua5x-nfoca9h\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\23b3802\sample\.venv\lib\site-packages (from opencv-python) (2.0.2)
# WARNING: You are using pip version 22.0.4; however, version 25.1.1 is available.
# You should consider upgrading via the 'C:\Users\23B3802\AppData\Local\uv\cache\archive-v0\bbIs7rTK5ua5x-NFOCa9h\Scripts\python.exe -m pip install --upgrade pip' command.
